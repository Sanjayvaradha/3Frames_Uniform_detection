# %%
# !pip install ultralytics

# %%
# !yolo task=detect mode=train epochs=100 data=/content/drive/MyDrive/Unform_detection.v13i.yolov8/data.yaml model=yolov8m.pt imgsz=640 batch=8 patience=8

# %% [markdown]
# **The classes**
#
# 0-> BSF
# 1-> CRPF
# 2-> jammu_kashmir_police

# %%
#Run this cell for prediction
# change the path of the model in "model" and path of the test data in "source"

# !yolo task=detect mode=predict model=/content/drive/MyDrive/Unform_detection.v13i.yolov8/best.pt source=/content/drive/MyDrive/Unform_detection.v13i.yolov8/157_jpg.rf.aab57e0f825295d5ceaca548025e95f8.jpg show=True conf=0.5
